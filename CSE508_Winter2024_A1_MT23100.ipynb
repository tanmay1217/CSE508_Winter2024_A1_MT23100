# %% [markdown]
# # # **Q1. Data Preprocessing [20 Marks]**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import nltk
nltk.download('punkt')
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ir1dataset/text_files/file314.txt
# /kaggle/input/ir1dataset/text_files/file998.txt
# /kaggle/input/ir1dataset/text_files/file603.txt
# /kaggle/input/ir1dataset/text_files/file175.txt
# /kaggle/input/ir1dataset/text_files/file457.txt
# /kaggle/input/ir1dataset/text_files/file565.txt
# /kaggle/input/ir1dataset/text_files/file349.txt
# /kaggle/input/ir1dataset/text_files/file65.txt
# /kaggle/input/ir1dataset/text_files/file634.txt
# /kaggle/input/ir1dataset/text_files/file988.txt
# /kaggle/input/ir1dataset/text_files/file185.txt
# /kaggle/input/ir1dataset/text_files/file615.txt
# /kaggle/input/ir1dataset/text_files/file620.txt
# /kaggle/input/ir1dataset/text_files/file491.txt
# /kaggle/input/ir1dataset/text_files/file911.txt
# /kaggle/input/ir1dataset/text_files/file354.txt
# /kaggle/input/ir1dataset/text_files/file27.txt
# /kaggle/input/ir1dataset/text_files/file595.txt
# /kaggle/input/ir1dataset/text_files/file622.txt
# /kaggle/input/ir1dataset/text_files/file11.txt
# ...

# %%
import os

# List to store filenames
filenames = []

# Iterate through the directory and extract filenames
for dirname, _, files in os.walk('/kaggle/input'):
    for filename in files:
        filenames.append(filename)

# Sort filenames numerically
sorted_filenames = sorted(filenames, key=lambda x: int(x.split('file')[1].split('.')[0]))
print(sorted_filenames)
# Print sorted filenames
#file1.txt  ... file999.txt
#for filename in sorted_filenames:
    #print(filename)
# Out:
# ['file1.txt', 'file2.txt', 'file3.txt', 'file4.txt', 'file5.txt', 'file6.txt', 'file7.txt', 'file8.txt', 'file9.txt', 'file10.txt', 'file11.txt', 'file12.txt', 'file13.txt', 'file14.txt', 'file15.txt', 'file16.txt', 'file17.txt', 'file18.txt', 'file19.txt', 'file20.txt', 'file21.txt', 'file22.txt', 'file23.txt', 'file24.txt', 'file25.txt', 'file26.txt', 'file27.txt', 'file28.txt', 'file29.txt', 'file30.txt', 'file31.txt', 'file32.txt', 'file33.txt', 'file34.txt', 'file35.txt', 'file36.txt', 'file37.txt', 'file38.txt', 'file39.txt', 'file40.txt', 'file41.txt', 'file42.txt', 'file43.txt', 'file44.txt', 'file45.txt', 'file46.txt', 'file47.txt', 'file48.txt', 'file49.txt', 'file50.txt', 'file51.txt', 'file52.txt', 'file53.txt', 'file54.txt', 'file55.txt', 'file56.txt', 'file57.txt', 'file58.txt', 'file59.txt', 'file60.txt', 'file61.txt', 'file62.txt', 'file63.txt', 'file64.txt', 'file65.txt', 'file66.txt', 'file67.txt', 'file68.txt', 'file69.txt', 'file70.txt', 'file71.txt', 'file72.txt'
# ...

# %%
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
import string

#lowercase removal
ip_directory = "/kaggle/input/ir1dataset/text_files/"
op_directory = "/kaggle/working/Lowercasethetext/"
#chk for directory exist or not
if not os.path.exists(op_directory):
    os.makedirs(op_directory)
lower_cased_data=[]
def preprocess_text(text):
    text = text.lower()
    return text
for filename in sorted_filenames:
    if filename.endswith(".txt"):
        ip_file_path = os.path.join(ip_directory, filename)
        op_file_path = os.path.join(op_directory, filename)
        with open(ip_file_path, 'r') as file:
            text = file.read()            
            preprocessed_text = preprocess_text(text)
            lower_cased_data.append(preprocessed_text)
            with open(op_file_path, 'w') as output_file:
                output_file.write(preprocessed_text)

# %%
#print lowercase removal
def print5examples(ip_directory):
    count=0
    for filename in sorted_filenames:
     if filename.endswith(".txt"):
            ip_file_path = os.path.join(ip_directory, filename)
            with open(ip_file_path, 'r') as file:
                text = file.read()
                print(text)
                print()
                count+=1
                if(count == 5):
                    break

#unprocessed data
print("Before Preprocessing the lowercase:\n")
ip_directory = "/kaggle/input/ir1dataset/text_files/"
print5examples(ip_directory)
#processed dir
print("\n\n\n")
print("After Preprocessing the lowercase:\n")
ip_directory = "/kaggle/working/Lowercasethetext/"
print5examples(ip_directory)
# Out:
# Before Preprocessing the lowercase:
#
# Loving these vintage springs on my vintage strat. They have a good tension and great stability. If you are floating your bridge and want the most out of your springs than these are the way to go.
#
# Works great as a guitar bench mat. Not rugged enough for abuse but if you take care of it, it will take care of you. Makes organization of workspace much easier because screws won't roll around. Color is good too.
#
# We use these for everything from our acoustic bass down to our ukuleles. I know there is a smaller model available for ukes, violins, etc.; we haven't yet ordered those, but these will work on smaller instruments if one doesn't extend the feet to their maximum width. They're gentle on the instruments, and the grippy material keeps them secure.
#
# The greatest benefit has been when writing music at the computer and needing to set a guitar down to use the keyboard/mouse - just easier for me than a hanging stand.
#
# ...

# %%
#Perform tokenization
ip_directory = "/kaggle/working/Lowercasethetext/"
op_directory = "/kaggle/working/Tokenize/"
#chk for directory exist or not
if not os.path.exists(op_directory):
    os.makedirs(op_directory)
def preprocess_text(text):
    tokens = word_tokenize(text)
    return tokens
tokenized_data=[]
for filename in sorted_filenames:
    if filename.endswith(".txt"):
        ip_file_path = os.path.join(ip_directory, filename)
        op_file_path = os.path.join(op_directory, filename)
        with open(ip_file_path, 'r') as file:
            text = file.read()            
            preprocessed_text = preprocess_text(text)
            tokenized_data.append(preprocessed_text)
            with open(op_file_path, 'w') as output_file:
                output_file.write(" ".join(preprocessed_text))

# %%
#print Tokenisation
def print5examples(ip_directory):
    flag=0
    if(ip_directory == "/kaggle/working/Tokenize/"):
        flag=1
    count=0
    for filename in sorted_filenames:
     if filename.endswith(".txt"):
            ip_file_path = os.path.join(ip_directory, filename)
            with open(ip_file_path, 'r') as file:
                text = file.read()
                if(flag==1):
                    text = word_tokenize(text)
                print(text)
                print()
                count+=1
                if(count == 5):
                    break

#unprocessed data
print("Before Preprocessing the Tokenization:\n")
ip_directory = "/kaggle/working/Lowercasethetext/"
print5examples(ip_directory)
#processed dir
print("\n\n\n")
print("After Preprocessing the Tokenization:\n")
ip_directory = "/kaggle/working/Tokenize/"
print5examples(ip_directory)
# Out:
# Before Preprocessing the Tokenization:
#
# loving these vintage springs on my vintage strat. they have a good tension and great stability. if you are floating your bridge and want the most out of your springs than these are the way to go.
#
# works great as a guitar bench mat. not rugged enough for abuse but if you take care of it, it will take care of you. makes organization of workspace much easier because screws won't roll around. color is good too.
#
# we use these for everything from our acoustic bass down to our ukuleles. i know there is a smaller model available for ukes, violins, etc.; we haven't yet ordered those, but these will work on smaller instruments if one doesn't extend the feet to their maximum width. they're gentle on the instruments, and the grippy material keeps them secure.
#
# the greatest benefit has been when writing music at the computer and needing to set a guitar down to use the keyboard/mouse - just easier for me than a hanging stand.
#
# ...

# %%
#Remove stopwords
ip_directory = "/kaggle/working/Tokenize/"
op_directory = "/kaggle/working/Stopwords/"
#chk for directory exist or not
if not os.path.exists(op_directory):
    os.makedirs(op_directory)
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    return tokens
no_stopwords_data=[]
for filename in sorted_filenames:
    if filename.endswith(".txt"):
        ip_file_path = os.path.join(ip_directory, filename)
        op_file_path = os.path.join(op_directory, filename)
        with open(ip_file_path, 'r') as file:
            text = file.read()            
            preprocessed_text = preprocess_text(text)
            no_stopwords_data.append(preprocessed_text)
            with open(op_file_path, 'w') as output_file:
                output_file.write(" ".join(preprocessed_text))

# %%
#print removal Stopwords
def print5examples(ip_directory):
    count=0
    for filename in sorted_filenames:
     if filename.endswith(".txt"):
            ip_file_path = os.path.join(ip_directory, filename)
            with open(ip_file_path, 'r') as file:
                text = file.read()
                text = word_tokenize(text)
                print(text)
                print()
                count+=1
                if(count == 5):
                    break

#unprocessed data
print("Before Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/Tokenize/"
print5examples(ip_directory)
#processed dir
print("\n\n\n")
print("After Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/Stopwords/"
print5examples(ip_directory)
# Out:
# Before Preprocessing the removal of Stopwords:
#
# ['loving', 'these', 'vintage', 'springs', 'on', 'my', 'vintage', 'strat', '.', 'they', 'have', 'a', 'good', 'tension', 'and', 'great', 'stability', '.', 'if', 'you', 'are', 'floating', 'your', 'bridge', 'and', 'want', 'the', 'most', 'out', 'of', 'your', 'springs', 'than', 'these', 'are', 'the', 'way', 'to', 'go', '.']
#
# ['works', 'great', 'as', 'a', 'guitar', 'bench', 'mat', '.', 'not', 'rugged', 'enough', 'for', 'abuse', 'but', 'if', 'you', 'take', 'care', 'of', 'it', ',', 'it', 'will', 'take', 'care', 'of', 'you', '.', 'makes', 'organization', 'of', 'workspace', 'much', 'easier', 'because', 'screws', 'wo', "n't", 'roll', 'around', '.', 'color', 'is', 'good', 'too', '.']
#
# ...

# %%
#Remove punctuations
ip_directory = "/kaggle/working/Stopwords/"
op_directory = "/kaggle/working/Punctuations/"
#chk for directory exist or not
if not os.path.exists(op_directory):
    os.makedirs(op_directory)
def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in string.punctuation]
    return tokens
no_punctuations_data=[]
for filename in sorted_filenames:
    if filename.endswith(".txt"):
        ip_file_path = os.path.join(ip_directory, filename)
        op_file_path = os.path.join(op_directory, filename)
        with open(ip_file_path, 'r') as file:
            text = file.read()            
            preprocessed_text = preprocess_text(text)  
            no_punctuations_data.append(preprocessed_text)
            with open(op_file_path, 'w') as output_file:
                output_file.write(" ".join(preprocessed_text))

# %%
#print removal Punctuations
def print5examples(ip_directory):
    count=0
    for filename in sorted_filenames:
     if filename.endswith(".txt"):
            ip_file_path = os.path.join(ip_directory, filename)
            with open(ip_file_path, 'r') as file:
                text = file.read()
                text = word_tokenize(text)
                print(text)
                print()
                count+=1
                if(count == 5):
                    break

#unprocessed data
print("Before Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/Stopwords/"
print5examples(ip_directory)
#processed dir
print("\n\n\n")
print("After Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/Punctuations/"
print5examples(ip_directory)
# Out:
# Before Preprocessing the removal of Stopwords:
#
# ['loving', 'vintage', 'springs', 'vintage', 'strat', '.', 'good', 'tension', 'great', 'stability', '.', 'floating', 'bridge', 'want', 'springs', 'way', 'go', '.']
#
# ['works', 'great', 'guitar', 'bench', 'mat', '.', 'rugged', 'enough', 'abuse', 'take', 'care', ',', 'take', 'care', '.', 'makes', 'organization', 'workspace', 'much', 'easier', 'screws', 'wo', "n't", 'roll', 'around', '.', 'color', 'good', '.']
#
# ...

# %%
#Remove blank space tokens
ip_directory = "/kaggle/working/Punctuations/"
op_directory = "/kaggle/working/BlankSpaces/"
#chk for directory exist or not
if not os.path.exists(op_directory):
    os.makedirs(op_directory)
def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.strip() != '']
    return tokens
finalize_data=[]
for filename in sorted_filenames:
    if filename.endswith(".txt"):
        ip_file_path = os.path.join(ip_directory, filename)
        op_file_path = os.path.join(op_directory, filename)
        with open(ip_file_path, 'r') as file:
            text = file.read()            
            preprocessed_text = preprocess_text(text) 
            finalize_data.append(preprocessed_text)
            with open(op_file_path, 'w') as output_file:
                output_file.write(" ".join(preprocessed_text))

# %%
#list of finalize_data after pre-processing
#finalize_data

# %%
#print removal BlankSpaces
def print5examples(ip_directory,flag):
    count=0
    for filename in sorted_filenames:
     if filename.endswith(".txt"):
            ip_file_path = os.path.join(ip_directory, filename)
            with open(ip_file_path, 'r') as file:
                text = file.read()
                text = word_tokenize(text)
                print(text)
                if(flag):
                    l.append(text)
                count=count+1
                print()
                
                if(count == 5):
                    break

l=[]
#unprocessed data
print("Before Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/Punctuations/"
print5examples(ip_directory,False)
#processed dir
print("\n\n\n")
print("After Preprocessing the removal of Stopwords:\n")
ip_directory = "/kaggle/working/BlankSpaces/"
print5examples(ip_directory,True)
# Out:
# Before Preprocessing the removal of Stopwords:
#
# ['loving', 'vintage', 'springs', 'vintage', 'strat', 'good', 'tension', 'great', 'stability', 'floating', 'bridge', 'want', 'springs', 'way', 'go']
#
# ['works', 'great', 'guitar', 'bench', 'mat', 'rugged', 'enough', 'abuse', 'take', 'care', 'take', 'care', 'makes', 'organization', 'workspace', 'much', 'easier', 'screws', 'wo', "n't", 'roll', 'around', 'color', 'good']
#
# ...

# %%
#print all data
#for i in range(len(finalize_data)):
    #print(f"doc{i+1}:\t", finalize_data[i],end="\n\n\n")

# %% [markdown]
# # # **Q2. Unigram Inverted Index and Boolean Queries [40 Marks]**

# %%
#1. Create a unigram inverted index (from scratch; No library allowed) of the dataset
#obtained from Q1 (after preprocessing).

# %%
def create_inverted_index(data):
    inverted_index = {}
    for doc_id, doc in enumerate(data, start=1):
        for word in doc:
            # Check given word is in the inverted index
            if word not in inverted_index:
                inverted_index[word] = []
            #Append the document ID to the respective list with that word 
            #p.s also handle duplicacy case
            if doc_id not in inverted_index[word]:
                inverted_index[word].append(doc_id)

    # Sort the inverted index by keys
    sorted_inverted_index = dict(sorted(inverted_index.items()))
    return sorted_inverted_index

sorted_inverted_index = create_inverted_index(finalize_data)
#print(type(sorted_inverted_index))
# Print the inverted index
for word, doc_ids in sorted_inverted_index.items():
    print(f"{word}: {doc_ids}")
# Out:
# '57: [346]
# '59: [936]
# '60s: [384]
# '63: [936]
# '78: [98, 565]
# '97: [721]
# 'buy: [324]
# 'clipped: [965]
# 'd: [11, 87, 125, 129, 155, 228, 260, 262, 336, 414, 429, 451, 483, 487, 519, 550, 572, 575, 618, 621, 629, 654, 741, 815, 825, 864, 938]
# 'keyboard: [616]
# 'll: [48, 52, 61, 89, 102, 134, 160, 182, 191, 200, 228, 233, 244, 267, 308, 343, 372, 373, 380, 404, 409, 413, 443, 449, 490, 491, 564, 573, 601, 640, 676, 680, 720, 731, 733, 760, 767, 777, 784, 788, 798, 805, 813, 873, 891, 906, 913, 937, 953, 985]
# ...

# %%
import pickle

# Save inverted index to a file using pickle
with open('sorted_inverted_index.pickle', 'wb') as f:
    pickle.dump(sorted_inverted_index, f)

# Load inverted index from the saved file
with open('sorted_inverted_index.pickle', 'rb') as f:
    load_inverted_index = pickle.load(f)

# Print the loaded inverted index
for word, doc_ids in load_inverted_index.items():
    print(f"{word}: {doc_ids}")
# Out:
# '57: [346]
# '59: [936]
# '60s: [384]
# '63: [936]
# '78: [98, 565]
# '97: [721]
# 'buy: [324]
# 'clipped: [965]
# 'd: [11, 87, 125, 129, 155, 228, 260, 262, 336, 414, 429, 451, 483, 487, 519, 550, 572, 575, 618, 621, 629, 654, 741, 815, 825, 864, 938]
# 'keyboard: [616]
# 'll: [48, 52, 61, 89, 102, 134, 160, 182, 191, 200, 228, 233, 244, 267, 308, 343, 372, 373, 380, 404, 409, 413, 443, 449, 490, 491, 564, 573, 601, 640, 676, 680, 720, 731, 733, 760, 767, 777, 784, 788, 798, 805, 813, 873, 891, 906, 913, 937, 953, 985]
# ...

# %%
def give_list(sorted_inverted_index,word):
    if word in sorted_inverted_index:
        return sorted(list(set(sorted_inverted_index[word])))

# %%
universe=[]
for i in range(1,1000):
    universe.append(i)

# %%
def do_and_operation(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def do_or_operation(list1,list2):
    result = sorted(list(set(list1).union(set(list2))))
    return result

def do_and_not_operation(list1, list2):
    notb = set(universe)-set(list2)
    return do_and_operation(list1,list(notb))     
        
def do_or_not_operation(list1,list2):
    notb = set(universe)-set(list2)
    return list(notb)

# %%
def do_something(listOfWords,op):
    l1=give_list(sorted_inverted_index,listOfWords[0]) 
    if(l1 == None):
        l1=[]
    l1_counter=1
    l2_counter=0
    for i in range(len(listOfWords)-1):
        print(listOfWords[l1_counter-1],op[l2_counter],end=" ")
        l2=give_list(sorted_inverted_index,listOfWords[l1_counter])
        if(l2 == None):
            l2=[]
        if(op[l2_counter] == "AND"):
            z=do_and_operation(l1,l2)
        elif(op[l2_counter] == "OR"):
            z=do_or_operation(l1,l2)
        elif(op[l2_counter] == "AND NOT"):
            z=do_and_not_operation(l1,l2)
        elif(op[l2_counter] == "OR NOT"):
            z=do_or_not_operation(l1,l2)
        l1=z
        l1_counter+=1
        l2_counter+=1
    print(listOfWords[-1])
    return z

# %%
def generate_output(input_list):
    output_list = ["File" + str(item) + ".txt" for item in input_list]
    return output_list

# %%
def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [word for word in tokens if word not in string.punctuation]
    tokens = [word for word in tokens if word.strip()]
    return tokens

# %%
#car bag canister
#OR,AND NOT
n=int(input())
for i in range(n):
    ip=input()
    ip = preprocess_text(ip)
    operator_ip=input().split(',')
    print(f"Query {i+1}:",end="")
    
    z=do_something(ip,operator_ip)
    print("Number of documents retrieved for query:",len(z))
    output_list = generate_output(z)
    for i in output_list:
        print(i,end=", ")
# Out:
#  1
#  Car bag in a canister
#  OR,AND NOT
# Query 1:car OR bag AND NOT canister
# Number of documents retrieved for query: 31
# File3.txt, File73.txt, File118.txt, File166.txt, File174.txt, File264.txt, File313.txt, File363.txt, File404.txt, File459.txt, File466.txt, File542.txt, File573.txt, File665.txt, File682.txt, File686.txt, File698.txt, File699.txt, File738.txt, File746.txt, File780.txt, File797.txt, File860.txt, File863.txt, File864.txt, File886.txt, File892.txt, File930.txt, File942.txt, File956.txt, File981.txt,

# %% [markdown]
# # # Q3. Positional Index and Phrase Queries [40 Marks]

# %%
import os
import nltk
import string
import pickle

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download NLTK resources
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    # Remove punctuations
    tokens = [word for word in tokens if word not in string.punctuation]
    
    # Remove blank space tokens
    tokens = [word for word in tokens if word.strip()]
    
    return tokens

# %%
# Function to create positional index
def create_positional_index(folder_path):
    positional_index = {}
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        with open(file_path, 'r') as file:
            text = file.read()
        
        tokens = preprocess_text(text)
        
        for position, token in enumerate(tokens):
            if token not in positional_index:
                positional_index[token] = {}
            if file_name not in positional_index[token]:
                positional_index[token][file_name] = []
            positional_index[token][file_name].append(position)
            
    return positional_index

# Function to save positional index using pickle
def save_positional_index(positional_index, file_path):
    with open(file_path, 'wb') as file:
        pickle.dump(positional_index, file)

# Function to load positional index using pickle
def load_positional_index(file_path):
    with open(file_path, 'rb') as file:
        positional_index = pickle.load(file)
    return positional_index

# %%
# Function to process queries using positional index
def process_queries(positional_index, queries):
    results = []
    for query in queries:
        query_terms = preprocess_text(query)
        retrieved_docs = None
        for term in query_terms:
            if term in positional_index:
                if retrieved_docs is None:
                    retrieved_docs = set(positional_index[term].keys())
                else:
                    retrieved_docs &= set(positional_index[term].keys())
        results.append(retrieved_docs)
    return results

# Function to get user input
def get_user_input():
    num_queries = int(input("Enter the number of queries to execute: "))
    queries = []
    for _ in range(num_queries):
        query = input("Enter phrase query: ")
        queries.append(query)
    return queries

# Function to display results
def display_results(results):
    for i, docs in enumerate(results, 1):
        print(f"Number of documents retrieved for query {i} using positional index: {len(docs)}")
        print(f"Names of documents retrieved for query {i} using positional index: {', '.join(docs)}")

# %%
def main():
    # Path to the folder containing your text files
    folder_path = '/kaggle/input/ir1dataset/text_files/'
    
    # Create positional index
    positional_index = create_positional_index(folder_path)
    
    # Save positional index
    save_positional_index(positional_index, 'positional_index.pickle')
    
    # Load positional index
    loaded_positional_index = load_positional_index('positional_index.pickle')
    
    # Get user input
    queries = get_user_input()
    
    # Process queries
    results = process_queries(loaded_positional_index, queries)
    
    # Display results
    display_results(results)


main()
# Out:
# Enter the number of queries to execute:  1
# Enter phrase query:  Car bag in a canister
# Number of documents retrieved for query 1 using positional index: 2
# Names of documents retrieved for query 1 using positional index: file174.txt, file886.txt
